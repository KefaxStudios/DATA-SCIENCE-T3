# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
from langdetect import detect
from deep_translator import GoogleTranslator

# %%
df = pd.read_csv('tasks 2\kilimall_appliances_listings.csv')

df.tail(15)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\k'
# <>:1: SyntaxWarning: invalid escape sequence '\k'
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_7488\201216582.py:1: SyntaxWarning: invalid escape sequence '\k'
#   df = pd.read_csv('tasks 2\kilimall_appliances_listings.csv')
#                                           product_name product_type  \
# 675  MK TV Guard// FRIDGE Guard//A FREE 4 Way Exten...   appliances
# 676                         Hisense 20L Microwave Oven   appliances
# 677  Dessini Multifunctional 8Litres Large Electric...   appliances
# 678  Handheld Fan Mini Portable Fan USB Personal Fa...   appliances
# 679  Nunix POWERFUL Electric Deep FRYER + FREE EXT....   appliances
# 680  4Pcs Anti Vibration Feet Pads Waterproof Legs ...   appliances
# 681  SWEEPER 3 IN 1 Smart Robot Vacuum Cleaner Auto...   appliances
# 682  Nunix Easily Portable Dry Iron Box - White And...   appliances
# 683  Water Bottle Pump Water Dispensers USB Recharg...   appliances
# ...

# %%
#removing the duplicates
df = df.drop_duplicates()

# %%
# Remove non-numeric characters
df["price"] = df["price"].str.replace(r"[^\d.]", "", regex=True)

# %%
df[10:50]
# Out:
#                                          product_name        product_type  \
# 10   Nokia 105, 1.77" screen, Dual SIM, Feature phone  phones-accessories
# 11  Luxurious look guaranteed for mobile phones,mo...  phones-accessories
# 12  RichRipple Y50 Pro Wireless Bluetooth Earphone...  phones-accessories
# 13  RichRipple 2 in 1 Smart Watch Men Women Blueto...  phones-accessories
# 14  PAFEL Bluetooth selfie stick 3in1 phones tripo...  phones-accessories
# 15  4PCS Tripod Stand Ring Light Phones Selfie Sti...  phones-accessories
# 16  Itel A70 128GB+8(3+5)GB RAM 6.6" Screen 4G Net...  phones-accessories
# 17  2024 New 3.5mm Wired Headphones In Ear Headset...  phones-accessories
# 18  Silicone Suction Cup Phone Case Mount , Phone ...  phones-accessories
# 19  Mini Portable USB LED Book Light DC5V Ultra Br...  phones-accessories
# 20  VEDO F9 Bluetooth Earphone Mini True Wireless ...  phones-accessories
# 21  Generic Ring Light Tripod 10Inch For Selfie,ma...  phones-accessories
# ...

# %%
# Convert 'price' column to integer
df["price"] = df["price"].astype(float)

# %%
df.dtypes
# Out:
# product_name            object
# product_type            object
# product_description    float64
# price                  float64
# link                    object
# dtype: object

# %%
df['product_name'][5]
# Out:
# 'Wireless Bluetooth Neckband Waterproof Sports Earphone with Sweatproof in-Ear Retractable Earbuds,Noise Cancelling Earphones For Workout, Running, Driving.'

# %%
#remove the pattern of anything enclosed in the brackets
df["product_name"] = df["product_name"].str.replace(r"【.*?】", "", regex=True).str.strip()

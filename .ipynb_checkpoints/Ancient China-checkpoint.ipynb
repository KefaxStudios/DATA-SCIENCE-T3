# %%
import pandas as pd
import numpy as np
import re
import nltk
import os
from collections import Counter

# %%
# import dataset in the csv format only
class FinancialPlanning():
    # check whether the file exists
    def file_exists(self, file_path):
        return os.path.isfile(file_path)
        
    def load_dataset(self, file_path):
        # if text == "default"
        # Load the dataset if it exists and also if it is a valid csv
        if not file_path.endswith ("csv"):
            raise ValueError("SORRY! You Provided an Unsupported File Format.")

            # return FileNotFoundError
        if not self.file_exists(file_path): # logic function to check if the file exists
            raise FileNotFoundError(f"OOOOPS! Your file '{file_path}' does not exist.")

        return pd.read_csv(file_path)
            
finance= FinancialPlanning()
file_path = r"C:\Kimani\Simba\CSVs\wikipedia_data_Ancient China.csv"

try:
    df = finance.load_dataset(file_path)
    print(df.head())

except Exception as e:
    print (e) # prints an error message if anything goes wrong

# this function only reads the csv filetype and otherwise will raise a ValueError
# Out:
#                            title  \
# 0               History of China
# 1                Ancient Chinese
# 2   Historical capitals of China
# 3       Outline of ancient China
# 4  Rhinoceroses in ancient China
#
#                                                  url  \
# 0     https://en.wikipedia.org/wiki/History_of_China
# 1      https://en.wikipedia.org/wiki/Ancient_Chinese
# 2  https://en.wikipedia.org/wiki/Historical_capit...
# 3  https://en.wikipedia.org/wiki/Outline_of_ancie...
# 4  https://en.wikipedia.org/wiki/Rhinoceroses_in_...
#
#                                              summary  \
# 0  Thehistory of Chinaspans several millennia acr...
# 1                       Ancient Chinesemay refer to:
# 2     This is a list ofhistorical capitals of China.
# 3  The followingoutlineis provided as an overview...
# 4  The existence ofrhinoceroses in ancient Chinai...
#
#                                              content  \
# 0                                                NaN
# 1  ## introduction\nAncient Chinesemay refer to:\...
# 2  ## introduction\nThis is a list ofhistorical c...
# 3  ## introduction\nThe followingoutlineis provid...
# 4  ## introduction\nThe existence ofrhinoceroses ...
#
#                                               images  \
# 0  https://upload.wikimedia.org/wikipedia/commons...
# 1  https://en.wikipedia.org/static/images/footer/...
# 2  https://en.wikipedia.org/static/images/footer/...
# 3  https://upload.wikimedia.org/wikipedia/commons...
# 4  https://upload.wikimedia.org/wikipedia/commons...
#
#                                           references  \
# 0  ^In his lifetime, Ying Zheng would have been k...
# 1                                                NaN
# 2  ^"中国四大古都的前世之谜-深度阅读 -".www.silkroads.org.cn. Re...
# 3  ^Tzu & Griffith (1963), p. v.sfnp error: no ta...
# 4  ^abcSickman, Laurence; Soper, Alexander (1971)...
#
#                                           categories
# 0                                   History of China
# 1                               Disambiguation pages
# 2  Ancient Chinese capitals,Lists of historical c...
# 3  Ancient China,Outlines of geography and places...
# 4  Ancient China,Rhinoceroses in popular culture,...

# %%
df['summary'].value_counts()
# Out:
# summary
# This is alist of political entities in the11th century BC(1100–1001 BC).                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      6
# This is an unofficial list ofUNESCOWorld Heritage Sitesaround the world by the religion they are associated with.[1]While some sites have had their religious affiliation changed at various points throughout history, this list categorizes sites by their most recent affiliation. Also, not all of the following sites are functioning as places of worship. UNESCO does not endorse classification by religion, which would be inconsistent with the universal value of these sites as "world heritage".                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 5
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    1
# Name: count, Length: 7266, dtype: int64

# %%
def detect_issues(df):
    # checks if the dataset has some common issues and report them
       print("\n **Dataset Overview**")
       print(df.info())
    
       print("\n **Missing Values")
       print(df.isnull().sum())
    
       print("\n **Duplicate Rows**")
       print(f"The total number of duplicates is:{df.duplicated().sum()}")
    
       print("\n **Inconsistent Datatypes**")
       print(df.apply(type).head())
    
df = pd.read_csv(r"C:\Kimani\Simba\CSVs\wikipedia_data_Ancient China.csv")
print (detect_issues(df))
# Out:
#  **Dataset Overview**
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9864 entries, 0 to 9863
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   title       9864 non-null   object
#  1   url         9864 non-null   object
#  2   summary     9835 non-null   object
#  3   content     7642 non-null   object
#  4   images      9864 non-null   object
#  5   references  9193 non-null   object
#  6   categories  9864 non-null   object
# dtypes: object(7)
# memory usage: 539.6+ KB
# None
#
#  **Missing Values
# title            0
# url              0
# summary         29
# content       2222
# images           0
# references     671
# categories       0
# dtype: int64
#
#  **Duplicate Rows**
# The total number of duplicates is:2577
#
#  **Inconsistent Datatypes**
# title      <class 'pandas.core.series.Series'>
# url        <class 'pandas.core.series.Series'>
# summary    <class 'pandas.core.series.Series'>
# content    <class 'pandas.core.series.Series'>
# images     <class 'pandas.core.series.Series'>
# dtype: object
# None

# %%
#removing the duplicates
df = df.drop_duplicates()
# check if the duplicates are gone
print("number of duplicate rows: ", df.duplicated())
# Out:
# number of duplicate rows:  0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9859    False
# 9860    False
# 9861    False
# 9862    False
# 9863    False
# Length: 7287, dtype: bool

# %%
missing_valuesdf1 = df.isnull()
for column in missing_valuesdf1.columns.values.tolist():
    print (missing_valuesdf1[column].value_counts())
    print("")
# Out:
# title
# False    7027
# Name: count, dtype: int64
#
# url
# False    7027
# Name: count, dtype: int64
#
# summary
# False    7027
# Name: count, dtype: int64
#
# content
# False    7027
# Name: count, dtype: int64
#
# images
# False    7027
# Name: count, dtype: int64
#
# references
# False    7027
# Name: count, dtype: int64
#
# categories
# False    7027
# Name: count, dtype: int64

# %%
df = df.dropna()
df
# Out:
#                               title  \
# 2      Historical capitals of China
# 3          Outline of ancient China
# 4     Rhinoceroses in ancient China
# 5             China–India relations
# 6             Ancient Chinese glass
# ...                             ...
# 9857             Polis (board game)
# 9858    The Longest Day in Chang'an
# 9859              Gungsong Gungtsen
# 9860                     Mu(shaman)
# 9862             Ferdinand Verbiest
#
#                                                     url  \
# 2     https://en.wikipedia.org/wiki/Historical_capit...
# 3     https://en.wikipedia.org/wiki/Outline_of_ancie...
# 4     https://en.wikipedia.org/wiki/Rhinoceroses_in_...
# 5     https://en.wikipedia.org/wiki/China–India_rela...
# 6     https://en.wikipedia.org/wiki/Ancient_Chinese_...
# ...                                                 ...
# 9857   https://en.wikipedia.org/wiki/Polis_(board_game)
# 9858  https://en.wikipedia.org/wiki/The_Longest_Day_...
# 9859    https://en.wikipedia.org/wiki/Gungsong_Gungtsen
# 9860          https://en.wikipedia.org/wiki/Mu_(shaman)
# 9862   https://en.wikipedia.org/wiki/Ferdinand_Verbiest
#
#                                                 summary  \
# 2        This is a list ofhistorical capitals of China.
# 3     The followingoutlineis provided as an overview...
# 4     The existence ofrhinoceroses in ancient Chinai...
# 5     ChinaandIndiahave historically maintained peac...
# 6     Ancient Chinese glassrefers to all types ofgla...
# ...                                                 ...
# 9857  Polis(Greek:πόλις,lit.'city-state') was ananci...
# 9858  The Longest Day in Chang'an(Chinese:长安十二时辰) is...
# 9859  649/655) was the only known son ofSongtsen Gam...
# 9860  Mu(Korean:무) is theKoreanterm for ashamaninKor...
# 9862  Ferdinand Verbiest,SJ(9 October 1623 – 28 Janu...
#
#                                                 content  \
# 2     ## introduction\nThis is a list ofhistorical c...
# 3     ## introduction\nThe followingoutlineis provid...
# 4     ## introduction\nThe existence ofrhinoceroses ...
# 5     ## introduction\nChinaandIndiahave historicall...
# 6     ## introduction\nAncient Chinese glassrefers t...
# ...                                                 ...
# 9857  ## introduction\nPolis(Greek:πόλις,lit.'city-s...
# 9858  ## introduction\nThe Longest Day in Chang'an(C...
# 9859  ## introduction\n649/655) was the only known s...
# 9860  ## introduction\nMu(Korean:무) is theKoreanterm...
# 9862  ## introduction\nFerdinand Verbiest,SJ(9 Octob...
#
#                                                  images  \
# 2     https://en.wikipedia.org/static/images/footer/...
# 3     https://upload.wikimedia.org/wikipedia/commons...
# 4     https://upload.wikimedia.org/wikipedia/commons...
# 5     https://upload.wikimedia.org/wikipedia/en/thum...
# 6     https://en.wikipedia.org/static/images/footer/...
# ...                                                 ...
# 9857  https://en.wikipedia.org/static/images/footer/...
# 9858  https://en.wikipedia.org/static/images/footer/...
# 9859  https://en.wikipedia.org/static/images/footer/...
# 9860  https://en.wikipedia.org/static/images/footer/...
# 9862  https://en.wikipedia.org/static/images/footer/...
#
#                                              references  \
# 2     ^"中国四大古都的前世之谜-深度阅读 -".www.silkroads.org.cn. Re...
# 3     ^Tzu & Griffith (1963), p. v.sfnp error: no ta...
# 4     ^abcSickman, Laurence; Soper, Alexander (1971)...
# 5     ^Backus, Maria (September 2002).Ancient China....
# 6     ^Braghin 2002a\n^Jenyns 1981\n^Pinder-Wilson 1...
# ...                                                 ...
# 9857  ^abcdefgKurke, Leslie (July 1999)."Ancient Gre...
# 9858  ^Gabriel Li (5 July 2019)."Youku's TV Series T...
# 9859  ^Snellgrove, David. 1987.Indo-Tibetan Buddhism...
# 9860  ^"About Korean shamanism and shamanistic ritua...
# 9862  ^abcdHerbermann, Charles, ed. (1913)."Ferdinan...
#
#                                              categories
# 2     Ancient Chinese capitals,Lists of historical c...
# 3     Ancient China,Outlines of geography and places...
# 4     Ancient China,Rhinoceroses in popular culture,...
# 5     China–India relations,Bilateral relations of C...
# 6     History of science and technology in China,His...
# ...                                                 ...
# 9857  Abstract strategy games,Traditional board game...
# 9858  2019 Chinese television series debuts,2019 Chi...
# 9859  7th-century Tibetan people,Emperors of Tibet,7...
# 9860                                   Korean shamanism
# 9862  Jesuit missionaries in China,Flemish priests,F...
#
# [7027 rows x 7 columns]

# %%
print(df.isnull().sum())
# Out:
# title         0
# url           0
# summary       0
# content       0
# images        0
# references    0
# categories    0
# dtype: int64

# %%
#this removes all the \n from the content table and summary
columns_to_clean = ["content", "summary", "title", "url", "references", "categories"]
df[columns_to_clean] = df[columns_to_clean].apply(lambda x: x.str.replace("\n", " ", regex=True))
# Out:
# C:\Users\kiman\AppData\Local\Temp\ipykernel_16020\2101638992.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[columns_to_clean] = df[columns_to_clean].apply(lambda x: x.str.replace("\n", " ", regex=True))

# %%
import string
def remove_url(text):
    if isinstance(text, str):
        return re.sub(r'https?://\S+|www\.\S+', '', text)
    return text

#This function removes punctuations
def remove_punct(text):
    if isinstance(text, str):
        return text.translate(str.maketrans('', '', string.punctuation))
    return text
        
columns_to_clean = ["content", "summary", "title", "url", "references", "categories"]
# Apply URL removal
df[columns_to_clean] = df[columns_to_clean].apply(remove_url)

# Apply punctuation removal if needed
df[columns_to_clean] = df[columns_to_clean].apply(remove_punct)
# Out:
# C:\Users\kiman\AppData\Local\Temp\ipykernel_16020\3527976520.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[columns_to_clean] = df[columns_to_clean].apply(remove_url)
# C:\Users\kiman\AppData\Local\Temp\ipykernel_16020\3527976520.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[columns_to_clean] = df[columns_to_clean].apply(remove_punct)

# %%
import wordninja
import pandas as pd

text_cols = ['summary', 'content', 'references', 'title', 'categories']
df[text_cols] = df[text_cols].fillna("").astype(str).applymap(lambda x: " ".join(wordninja.split(x)))
# Out:
# C:\Users\kiman\AppData\Local\Temp\ipykernel_16020\1474499009.py:5: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df[text_cols] = df[text_cols].fillna("").astype(str).applymap(lambda x: " ".join(wordninja.split(x)))
# C:\Users\kiman\AppData\Local\Temp\ipykernel_16020\1474499009.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[text_cols] = df[text_cols].fillna("").astype(str).applymap(lambda x: " ".join(wordninja.split(x)))

# %%
# Removing special characters from the columns
cols_to_clean =  ['summary', 'content', 'references', 'title', 'categories']
# Apply regex to these columns
df[cols_to_clean]=df[cols_to_clean].fillna('').apply(
    lambda col: col.str.replace("r[^\w\s]", "", regex=True).str.replace("\n", " ", regex=True)
)
df.head()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\w'
# <>:5: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\kiman\AppData\Local\Temp\ipykernel_16020\759871531.py:5: SyntaxWarning: invalid escape sequence '\w'
#   lambda col: col.str.replace("r[^\w\s]", "", regex=True).str.replace("\n", " ", regex=True)
# C:\Users\kiman\AppData\Local\Temp\ipykernel_16020\759871531.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[cols_to_clean]=df[cols_to_clean].fillna('').apply(
#                            title url  \
# 2   Historical capitals of China
# 3       Outline of ancient China
# 4  Rhinoceroses in ancient China
# 5          China India relations
# 6          Ancient Chinese glass
#
#                                              summary  \
# 2     This is a list of historical capitals of China
# 3  The following outline is provided as an overvi...
# 4  The existence of rhinoceroses in ancient China...
# 5  China and India have historically maintained p...
# 6  Ancient Chinese glass refers to all types of g...
#
#                                              content  \
# 2  introduction This is a list of historical capi...
# 3  introduction The following outline is provided...
# 4  introduction The existence of rhinoceroses in ...
# 5  introduction China and India have historically...
# 6  introduction Ancient Chinese glass refers to a...
#
#                                               images  \
# 2  https://en.wikipedia.org/static/images/footer/...
# 3  https://upload.wikimedia.org/wikipedia/commons...
# 4  https://upload.wikimedia.org/wikipedia/commons...
# 5  https://upload.wikimedia.org/wikipedia/en/thum...
# 6  https://en.wikipedia.org/static/images/footer/...
#
#                                           references  \
# 2  Retrieved 20240217 Denis Twitch ett Herbert Fr...
# 3  Tzu Griffith 1963 p vs f np error no target CI...
# 4  abc Sick man Laurence So per Alexander 1971 Th...
# 5  Backus Maria September 2002 Ancient China Lore...
# 6  Brag h in 2002 a Jen yn s 1981 Pinder Wilson 1...
#
#                                           categories
# 2  Ancient Chinese capitals Lists of historical c...
# 3  Ancient China Outlines of geography and places...
# 4  Ancient China Rhinoceroses in popular culture ...
# 5  China India relations Bilateral relations of C...
# 6  History of science and technology in China His...

# %%
df['summary'].value_counts()
# Out:
# summary
# This is a list of political entities in the 11 th century BC 1100 1001 BC                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                
# Name: count, Length: 5214, dtype: int64

# %%
# Normalize the Dataframe
# convert the text to lower case
text_cols = ['title','content', 'summary','categories', 'references']
for col in text_cols:
    df[col] = df[col].astype(str).str.lower()
# Out:
# C:\Users\kiman\AppData\Local\Temp\ipykernel_16020\1780614303.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].astype(str).str.lower()
# C:\Users\kiman\AppData\Local\Temp\ipykernel_16020\1780614303.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].astype(str).str.lower()
# C:\Users\kiman\AppData\Local\Temp\ipykernel_16020\1780614303.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].astype(str).str.lower()
# C:\Users\kiman\AppData\Local\Temp\ipykernel_16020\1780614303.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].astype(str).str.lower()
# C:\Users\kiman\AppData\Local\Temp\ipykernel_16020\1780614303.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].astype(str).str.lower()

# %%
import re
from calendar import month_name

# Create a dictionary mapping month names to numbers
month_to_num = {name.lower(): f"{i:02}" for i, name in enumerate(month_name) if i}

# Patterns for date formats
full_date_pattern = re.compile(
    r'\b(' + '|'.join(month_to_num.keys()) + r')\s+(\d{1,2})\s+(\d{4})\b', flags=re.IGNORECASE
)
month_year_pattern = re.compile(
    r'\b(' + '|'.join(month_to_num.keys()) + r')\s+(\d{4})\b', flags=re.IGNORECASE
)

# Sample text
sample_text = "The shuttle mission was completed on March 9 2011 and another mission happened in July 2011."

# Find matches
full_matches = full_date_pattern.findall(sample_text)
month_year_matches = month_year_pattern.findall(sample_text)

print("Full Date Matches:", full_matches)
print("Month-Year Matches:", month_year_matches)
# Out:
# Full Date Matches: [('March', '9', '2011')]
# Month-Year Matches: [('July', '2011')]

# %%
# Regex for YYYYMMDD dates
yyyymmdd_pattern = re.compile(r'\b(20\d{6})\b')

def standardize_full_date(match):
    """Convert 'March 9 2011' to '2011-03-09'."""
    month_str, day, year = match.groups()
    month_num = month_to_num.get(month_str.lower(), "00")  # Default to '00' if not found
    day_formatted = f"{int(day):02}"  # Ensure day is two digits
    return f"{year}-{month_num}-{day_formatted}"

def standardize_month_year(match):
    """Convert 'July 2011' to '2011-07'."""
    month_str, year = match.groups()
    month_num = month_to_num.get(month_str.lower(), "00")
    return f"{year}-{month_num}"


def standardize_yyyymmdd(match):
    """Convert 'YYYYMMDD' to 'YYYY-MM-DD'."""
    date_str = match.group(1)
    return f"{date_str[:4]}-{date_str[4:6]}-{date_str[6:]}"  # Format as YYYY-MM-DD

# Update process_dates function to include this new pattern
def process_dates(text):
    # Standardize full dates (e.g., "March 9 2011" -> "2011-03-09")
    text = full_date_pattern.sub(standardize_full_date, text)

    # Standardize month-year dates (e.g., "July 2011" -> "2011-07")
    text = month_year_pattern.sub(standardize_month_year, text)

    # Standardize YYYYMMDD format (e.g., "20220405" -> "2022-04-05")
    text = yyyymmdd_pattern.sub(standardize_yyyymmdd, text)

    return text

# %%
df['content'] = df['content'].astype(str).apply(process_dates)
df['summary'] = df['summary'].astype(str).apply(process_dates)
# Out:
# C:\Users\kiman\AppData\Local\Temp\ipykernel_16020\248794021.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['content'] = df['content'].astype(str).apply(process_dates)
# C:\Users\kiman\AppData\Local\Temp\ipykernel_16020\248794021.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['summary'] = df['summary'].astype(str).apply(process_dates)

# %%
df.to_csv('mikek.csv', index=False)
